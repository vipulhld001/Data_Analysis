# %% [markdown]
# <table>
# <tr>
# <td width=15%><img src="https://www.nitrkl.ac.in/assets/images/logo.png"></img></td>
# <td><center><h1>National Institute of Technology
# Rourkela, Odisha, India, 769008</h1><h2>Department of Computer Science Engineering</h2></center></td>
# </tr>
# <tr><td colspan=2><center><h3>RESEARCH INTERNSHIP
# </h3></br>
#             <b>(on
# Internet of Things (IoT) and Data Analytics)</b></center></td></tr>
# </table>

# %% [markdown]
# # Part 1 - Visualization Data

# %% [markdown]
# ### We will be using matplotlib Library to visualizing the data
# ``` python
# !pip install matplotlib
#
# ```

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.11.0-cp311-cp311-win_amd64.whl (9.3 MB)
# ...
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# ...
#   Using cached fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
# ...
#      ---------------------------------------- 7.1/7.1 MB 4.6 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Line Chart

# %%
import numpy as np
from matplotlib import pyplot as plt
years = [1950,1960,1970,1980,1990,2000,2010]
gdp= [300.2,543.3,1075.9,2862.5,5979.6,10289.7,14958.3]

# Create a line chart , years on X-axis , gdp on y-axis
plt.plot(years,gdp,color = 'pink', marker = 'o',linestyle = 'solid')

# Add a title
plt.title("nominal GDP")

# Add a label to the y-axis
plt.ylabel("Billions of $")
plt.show()

# %% [markdown]
# # Enumerate
# ## Loopin with Index

# %%
fruits = ['apple', 'banana', 'cherry']
enum_fruits = enumerate(fruits)
print(list(enum_fruits))
# Out:
# [(0, 'apple'), (1, 'banana'), (2, 'cherry')]

# %%
_, a = 1,2
print(_)
# Out:
# 1

# %%
for _ in range(3):
    print("Hello,world!")
# Out:
# Hello,world!
# Hello,world!
# Hello,world!

# %% [markdown]
# # Bar Charts
#
# ## A bar chart (aka bar graph, column chart) plots numeric values for levels of a categorical feature as bars. Levels are plotted on one chart axis, and values are plotted on the other axis. Each categorical value claims one bar, and the length of each bar corresponds to the bar’s value. Bars are plotted on a common baseline to allow for easy comparison of values.

# %%
from matplotlib import pyplot as plt
movies = ["Annie Hall","Green Book", "Casablanca", "Gandhi" , "Oppenheimer"]
oscars = [5,3,3,8,7]

# bars are by default width 0.8 , so we'll add 0.1 to the left coordinates , so that each bar is centered
xs = [i + 0.1 for i,_ in enumerate(movies)]

# plt bars with left x-coordinates [xs] , heights [oscars] 
plt.bar(xs , oscars)
plt.ylabel("# of academy awards")
plt.title("My favourite movies")

# label x axis with movie names at bar centers 
plt.xticks([i + 0.15 for i , _ in enumerate(movies)],movies)
plt.show()

# %% [markdown]
# # In Python, the zip() function is used to combine two or more lists (or any other iterables) into a single iterable, where elements from corresponding positions are paired together. The resulting iterable contains tuples, where the first element from each list is paired together, the second element from each list is paired together, and so on.

# %%
name = [ "Manjeet", "Nikhil", "Shambhavi", "Astha" ]
roll_no = [ 5, 1, 3, 1 ,4]
 
# using zip() to map values
mapped = zip(name, roll_no)
 
print(set(mapped))
# Out:
# {('Manjeet', 5), ('Astha', 1), ('Nikhil', 1), ('Shambhavi', 3)}

# %%
names = ['Mukesh', 'Roni', 'Chari']
ages = [24, 50, 18]

for i, (name, age) in enumerate(zip(names, ages)):
	print(i, name, age)
# Out:
# 0 Mukesh 24
# 1 Roni 50
# 2 Chari 18

# %% [markdown]
# ## Line Charts

# %%
variance = [1,2,4,8,16,32,64,128,256]
bias_squared = [256, 128, 64 ,32,  16, 8, 4, 2, 1]
total_error = [x+y for x, y in zip(variance, bias_squared)]
xs = [i for i , _ in enumerate(variance)]

# we can make multiple calls to plt.plot
# to show multiple series on the same chart
plt.plot(xs , variance , 'g-' , label = 'variance')
plt.plot(xs , bias_squared , 'r-.' , label = 'bias^2')
plt.plot(xs , total_error , 'b:' , label = 'total error')

plt.legend(loc = 9)
plt.xlabel("model complexity")
plt.title("The bias-varience tradeoff")
plt.show()

# %% [markdown]
# # Scatterplots
# ## A scatter plot is a data visualization that uses dots to represent the values of two different numeric variables. The position of each dot on a horizontal (X) and vertical (Y) axis indicates its specific value, allowing you to easily identify relationships, patterns, or correlations between the two variables

# %%
friends = [70,65,72,63,71,64,60,64,67]
mins = [175,170,205,120,220,130,105,145,190]
labels = ["a","b","c","d","e","f","g","h","i"]

plt.scatter(friends,mins)
for label , friend_count , mins_count in zip(labels,friends,mins):
    plt.annotate(label,
                xy = (friend_count,mins_count),
                xytext = (5,-5),
                textcoords = "offset points")
plt.title("Daily minutes vs No of friends")
plt.xlabel("No of friends")
plt.ylabel("mins spent on website")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey_results_public.csv')

# %%
df.columns
df.dtypes.to_frame(name = "Data Type")
df.info(max_cols= None)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  str
#  2   Hobbyist                88883 non-null  str
#  3   OpenSourcer             88883 non-null  str
#  4   OpenSource              86842 non-null  str
#  5   Employment              87181 non-null  str
#  6   Country                 88751 non-null  str
#  7   Student                 87014 non-null  str
#  8   EdLevel                 86390 non-null  str
#  9   UndergradMajor          75614 non-null  str
#  10  EduOther                84260 non-null  str
#  11  OrgSize                 71791 non-null  str
#  12  DevType                 81335 non-null  str
#  13  YearsCode               87938 non-null  str
#  14  Age1stCode              87634 non-null  str
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df["Age"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["CodeRevHrs"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey_results_public.csv')
df.columns = df.columns.astype(str)


top_countries = df['Country'].value_counts().nlargest(10).index
df_filtered = df[df['Country'].isin(top_countries)]

# Count Genders per Country
# We use groupby and unstack to pivot the data for plotting
country_gender_counts = df_filtered.groupby(['Country', 'Gender']).size().unstack(fill_value=0)

# Plot as a stacked bar chart
country_gender_counts.plot(kind='bar', stacked=True, figsize=(12, 6))

# Clean up the layout and show
plt.title('Gender Distribution Across Top 10 Countries (Stack Overflow 2024)')
plt.xlabel('Country')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %% [markdown]
# ---
# # Part 2 - Linear Algebra
#
# ---

# %% [markdown]
# ### Get a row from matrix

# %%
def get_row(M,i):
    return M[i]
M = np.array([[0,2,1,3], 
             [3,2,8,1], 
             [1,0,0,3],
             [0,3,2,1]])
get_row(M,2)
# Out:
# array([1, 0, 0, 3])

# %% [markdown]
# ### Get a Column from matrix

# %%
def get_col(M,j):
    return [M_i[j] for M_i in M] 
M = np.array([[0,2,1,3], 
             [3,2,8,1], 
             [1,0,0,3],
             [0,3,2,1]])
get_col(M,2)
# Out:
# [1, 8, 0, 2]

# %% [markdown]
# ### Create a row vector and column vector, and show the shape of the vectors.

# %%
import numpy as np
vector_row = np.array([[1, -5, 3, 2, 4]])
vector_column = np.array([[1], 
                          [2], 
                          [3], 
                          [4]])
print(vector_row.shape)
print(vector_column.shape)
# Out:
# (1, 5)
# (4, 1)

# %% [markdown]
# # What are Vector Norms?
# ## A vector norm is a function that assigns a non-negative scalar value to a vector. The value represents the length or magnitude of the vector. Vector norms are fundamental mathematical concepts that allow us to measure the distance or difference between two vectors. Vector norms are widely used in various fields such as optimization, machine learning, computer graphics, and signal processing.
#
# # There are different types of vector norms such as the L0 norm, L1 norm, L2 norm (Euclidean norm), and L-infinity norm. Each type of vector norm has its unique properties and applications.

# %% [markdown]
# ### The L0 norm of a vector counts the number of non-zero elements in the vector. The L0 norm is an essential concept in compressive sensing, a technique for reconstructing images from a sparse set of measurements. The L0 norm is also used in machine learning for feature selection. In the L0 norm, the cost function is non-convex, making it challenging to optimize. There’s a later section in this blog on the challenges of vector norms.

# %% [markdown]
# ### The L1 norm is a vector norm that sums up the absolute values of the vector elements. The L1 norm is defined as `||x||1 = ∑|xi|`. The L1 norm is used in machine learning for regularization and feature selection. The L1 norm produces sparse solutions and is computationally efficient.

# %% [markdown]
# ![0_1kmU2e3eDsPGJjvR.webp](attachment:0_1kmU2e3eDsPGJjvR.webp)

# %% [markdown]
# ### The L2 norm, also known as the “Euclidean norm,” is a vector norm that measures the length or magnitude of a vector in Euclidean space. The L2 norm is defined as
# ### `||x||2 = sqrt(∑xi^2)`. The L2 norm is widely used in machine learning and optimization as a loss function or objective function. The L2 norm produces smooth solutions, making it easy to optimize. The L2 norm is also used in image reconstruction accuracy measurements, where the error is calculated as the L2 norm of the difference between the original and the reconstructed image.

# %% [markdown]
# ![0_HTlIui8sHP8pIHBW.webp](attachment:0_HTlIui8sHP8pIHBW.webp)

# %% [markdown]
# ### The L-infinity norm, also known as the “max norm,” is a vector norm that measures the maximum absolute value of the vector elements. The L-infinity norm is defined as
# ### `||x||∞ = max|xi|`. The L-infinity norm is used in machine learning for regularization, where the goal is to minimize the maximum absolute value of the model parameters

# %% [markdown]
# ### Transpose the row vector we defined above into a column vector and calculate the 𝐿1, L2𝐿, and L∞ norm of it.

# %%
from numpy.linalg import norm
new_vector = vector_row.T
print(new_vector)
norm_1 = norm(new_vector, 1)
norm_2 = norm(new_vector, 2)
norm_inf = norm(new_vector, np.inf)
print('L_1 is: %.1f'%norm_1)
print('L_2 is: %.1f'%norm_2)
print('L_inf is: %.1f'%norm_inf)
# Out:
# [[ 1]
#  [-5]
#  [ 3]
#  [ 2]
#  [ 4]]
# L_1 is: 15.0
# L_2 is: 7.4
# L_inf is: 5.0

# %% [markdown]
# ### Compute the angle between the vectors v=[10,9,3] and w = [2,5,12]

# %% [markdown]
# ![1_ZBoj7xtOfiPyub7JF4WEEQ.webp](attachment:1_ZBoj7xtOfiPyub7JF4WEEQ.webp)

# %% [markdown]
# ## The `arccos()` method computes the arccosine (inverse cosine) of each element in an array.

# %%
from numpy import arccos, dot

v = np.array([[10, 9, 3]])
w = np.array([[2, 5, 12]])
theta = arccos(dot(v, w.T)/(norm(v)*norm(w)))
print(theta)
# Out:
# [[0.97992471]]

# %% [markdown]
# ### Given the vectors `v=[2,3,4]` and `w=[5,6,7]` . Use the Numpy function cross to compute the cross product of v and w.

# %% [markdown]
# ![1_MmNYJkoSJO28XlBpibByZA.webp](attachment:1_MmNYJkoSJO28XlBpibByZA.webp)

# %%
v = np.array([[2, 3, 4]])
w = np.array([[5, 6, 7]])
print(np.cross(v, w))
# Out:
# [[-3  6 -3]]

# %% [markdown]
# ### Given the row vectors v=[0,3,2] and w = [4,1,1] and u = [0,-2,0] . Write the vector x = [-8,-1,4] as a linear combination of v , w ,u
#
# # `av +bw + cu = x`

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v = np.array([[0, 3, 2]])
w = np.array([[4, 1, 1]])
u = np.array([[0, -2, 0]])
x = 3*v-2*w+4*u
print(x)
# Out:
# [[-8 -1  4]]

# %% [markdown]
# ### Let the Python matrices P=[[1,7] ,[2,3] , [5,0]] and Q=[[2,6,3,1],[1,2,3,4]] . Compute the matrix product of P and Q. Show that the product of Q and P will produce an error.

# %%
P = np.array([[1, 7], [2, 3], [5, 0]])
Q = np.array([[2, 6, 3, 1], [1, 2, 3, 4]])
print(P)
print(Q)
print(np.dot(P, Q))
np.dot(Q, P)
# Out:
# [[1 7]
#  [2 3]
#  [5 0]]
# [[2 6 3 1]
#  [1 2 3 4]]
# [[ 9 20 24 29]
#  [ 7 18 15 14]
#  [10 30 15  5]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 6
#       4 print(Q)
#       5 print(np.dot(P, Q))
# ----> 6 np.dot(Q, P)
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# ValueError: shapes (2,4) and (3,2) not aligned: 4 (dim 1) != 3 (dim 0)

# %% [markdown]
# ### Finding Determinate

# %%
from numpy.linalg import det

M = np.array([[0,2,1,3], 
             [3,2,8,1], 
             [1,0,0,3],
             [0,3,2,1]])
print('M:\n', M)

print('Determinant: %.1f'%det(M))
# Out:
# M:
#  [[0 2 1 3]
#  [3 2 8 1]
#  [1 0 0 3]
#  [0 3 2 1]]
# Determinant: -38.0

# %% [markdown]
# ### Finding Inverse of matrix
# #### The function numpy.linalg.inv() is available in the NumPy module and is used to compute the inverse matrix in Python.

# %%
# Import required package
import numpy as np

# Taking a 3 * 3 matrix
A = np.array([[6, 1, 1],
              [4, -2, 5],
              [2, 8, 7]])

# Calculating the inverse of the matrix
print("Inverse of matrix is : ")
print(np.linalg.inv(A))
# Out:
# Inverse of matrix is :
# [[ 0.17647059 -0.00326797 -0.02287582]
#  [ 0.05882353 -0.13071895  0.08496732]
#  [-0.11764706  0.1503268   0.05228758]]

# %% [markdown]
# ## ____________________________________________________________________________
#
# # Part 3 - Statistics

# %% [markdown]
# ### Describing a Single Set of Data

# %%
import pandas as pd
import numpy as np

# Create a sample dataset
data = {'Scores': [70, 85, 90, 75, 80, 95, 88, 92, 78, 82]}
df = pd.DataFrame(data)
df
# Out:
#    Scores
# 0      70
# 1      85
# 2      90
# 3      75
# 4      80
# 5      95
# 6      88
# 7      92
# 8      78
# 9      82

# %% [markdown]
# ### Summary Statistics
# ### We can get a quick overview of the dataset using the describe() method.

# %%
df.describe()
# Out:
#           Scores
# count  10.000000
# mean   83.500000
# std     7.947746
# min    70.000000
# 25%    78.500000
# 50%    83.500000
# 75%    89.500000
# max    95.000000

# %% [markdown]
# # Central Tendencies
# ## Central tendency refers to the "center" or typical value of a dataset. It is a descriptive summary that condenses large amounts of data into a single representative number to help you understand the overall distribution and spot general patterns
# Central tendency measures include the mean, median, and mode.

# %%
# Mean
mean_score = df['Scores'].mean()
print(f'Mean: {mean_score}')

# Median
median_score = df['Scores'].median()
print(f'Median: {median_score}')

# Mode
mode_score = df['Scores'].mode().iloc[0]
print(f'Mode: {mode_score}')
# Out:
# Mean: 83.5
# Median: 83.5
# Mode: 70

# %% [markdown]
# # Dispersion
# ## Calculating dispersion helps you understand how spread out or varied the data points are in a dataset. The most common methods are Range, Variance, Standard Deviation, and Interquartile Range (IQR)
# Finding range, variance, and standard deviation.

# %%
# Range
range_score = df['Scores'].max() - df['Scores'].min()
print(f'Range: {range_score}')

# Variance
variance_score = df['Scores'].var()   # Variance measures how spread out a set of data points are from their average (mean).
print(f'Variance: {variance_score}')

# Standard Deviation
std_deviation_score = df['Scores'].std()
print(f'Standard Deviation: {std_deviation_score}')
# Out:
# Range: 25
# Variance: 63.166666666666664
# Standard Deviation: 7.947746011710909

# %% [markdown]
# ## Use standard deviation for practical, real-world data interpretation (like reporting results in original units), and use variance for mathematical operations, portfolio theory, and advanced statistical modeling where squared properties are highly advantageous.

# %% [markdown]
# ## Correlation
# Correlation measures the relationship between two variables.

# %%
# Create a second dataset
data['Study Hours'] = [2, 3, 4, 1, 3, 5, 4, 5, 2, 3]
df = pd.DataFrame(data)
df
# Out:
#    Scores  Study Hours
# 0      70            2
# 1      85            3
# 2      90            4
# 3      75            1
# 4      80            3
# 5      95            5
# 6      88            4
# 7      92            5
# 8      78            2
# 9      82            3

# %% [markdown]
# ## Correlation Coefficient
#
# For more [info](https://www.scribbr.com/statistics/correlation-coefficient/)

# %%
correlation = df['Scores'].corr(df['Study Hours'])
print(f'Correlation between Scores and Study Hours: {correlation}')
# Out:
# Correlation between Scores and Study Hours: 0.9238292719140375

# %% [markdown]
# ## Simpson's Paradox
# Simpson's Paradox occurs when a trend appears in different groups of data but disappears or reverses when these groups are combined.

# %%
# Create a dataset illustrating Simpson's Paradox
data = {'Group': ['A', 'A', 'B', 'B', 'A', 'A', 'B', 'B'],
        'Treatment': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No'],
        'Success': [20, 5, 2, 1, 4, 1, 20, 5],
        'Total': [25, 25, 5, 5, 5, 5, 25, 25]}
df_simpson = pd.DataFrame(data)
df_simpson['Success Rate'] = df_simpson['Success'] / df_simpson['Total']
df_simpson
# Out:
#   Group Treatment  Success  Total  Success Rate
# 0     A       Yes       20     25           0.8
# 1     A        No        5     25           0.2
# 2     B       Yes        2      5           0.4
# 3     B        No        1      5           0.2
# 4     A       Yes        4      5           0.8
# 5     A        No        1      5           0.2
# 6     B       Yes       20     25           0.8
# 7     B        No        5     25           0.2

# %%
# Success Rates by Group and Treatment
grouped = df_simpson.groupby(['Group', 'Treatment']).sum()
grouped['Success Rate'] = grouped['Success'] / grouped['Total']
grouped
# Out:
#                  Success  Total  Success Rate
# Group Treatment
# A     No               6     30      0.200000
#       Yes             24     30      0.800000
# B     No               6     30      0.200000
#       Yes             22     30      0.733333
